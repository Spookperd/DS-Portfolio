# %% [markdown]
# # Data Visualization
#
# In this notebook, we will demonstrate data visualization skills using the Automobile dataset.

# %% [markdown]
# ## Import Libraries and Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Auto_Data_Proc.csv')
df.head()
# Out:
#    Unnamed: 0         make fuel-type aspiration num-of-doors   body-style  \
# 0           0  alfa-romero       gas        std          two  convertible
# 1           1  alfa-romero       gas        std          two  convertible
# 2           2  alfa-romero       gas        std          two    hatchback
# 3           3         audi       gas        std         four        sedan
# 4           4         audi       gas        std         four        sedan
#
#   drive-wheels engine-location  wheel-base    length  ...  engine-size  \
# 0          rwd           front        88.6  0.811148  ...          130
# 1          rwd           front        88.6  0.811148  ...          130
# 2          rwd           front        94.5  0.822681  ...          152
# 3          fwd           front        99.8  0.848630  ...          109
# 4          4wd           front        99.4  0.848630  ...          136
#
#    fuel-system  bore stroke compression-ratio  horsepower peak-rpm  price  \
# ...

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### Scatterplot of engine-size vs. price

# %%
plt.scatter(df['engine-size'], df['price'])
plt.xlabel('Engine Size')
plt.ylabel('Price')
plt.title('Engine Size vs. Price')
plt.show()

# %% [markdown]
# ### Boxplot of price by body-style

# %%
sns.boxplot(x='body-style', y='price', data=df)
plt.title('Price by Body Style')
plt.show()

# %% [markdown]
# ### Histogram of price

# %%
plt.hist(df['price'].dropna().astype(float), bins=10)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Price Distribution')
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this notebook, we demonstrated data visualization skills by creating scatterplots, boxplots, and histograms using the Automobile dataset.
